# %% [markdown]
# <a href="https://colab.research.google.com/github/bhardwajchetna/Zero-shot-Classifier/blob/main/Cheatsheet_Zero_shot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing the packages
# !pip install ftfy
# !pip install spacy
# !pip install transformers
# Out:
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/dist-packages (6.0.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from ftfy) (0.2.5)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (56.1.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.4.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.6.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.0.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import ftfy
import string
import pprint
import re, nltk, spacy
from torch.optim.adam import Adam
from transformers import pipeline
from numpy import argmax

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Step 1: Reading the input files

# Replace here the name of csv file containing reviews
reviews = pd.read_csv('/content/gdrive/Shareddrives/Job Prep/cheatsheet docs/Google_Reviews.csv')

# Replace here the csv file of classes that you want to predict using descriptive names
layers = pd.read_csv('/content/gdrive/Shareddrives/Job Prep/cheatsheet docs/layers.csv')

# %%
# A look into format of Reviews file
reviews.head(10)
# Out:
#                                                 text
# 0  My husband and I recently received our second ...
# 1  Miss Teal up on the 2nd floor in Optical Dept ...
# 2  If I could give this hospital negative stars I...
# 3  Don’t be fooled by their awards and notoriety....
# 4  Very disappointing ER experience.\nThe room we...
# 5  I got my COVID vaccination, today at UCDAVIS M...
# 6  Working in EMS currently waiting a wall time o...
# 7  I brought my father here after he was hospital...
# 8  My Mom was in ER from Wednesday 11am until adm...
# 9  Very unprofessional people. No compassion what...

# %%
# A look into format of classes & subclasses to predict
layers.head(10)
# Out:
#                Subtheme               Subclass1  ...      Subclass5 Subclass6
# 0            Medication         Pain Management  ...  Communication       NaN
# 1            Cleaniless            Patient Area  ...            NaN       NaN
# 2  Physical Enviornment                   Noise  ...            NaN       NaN
# 3         Communication                  Doctor  ...            NaN       NaN
# 4              Behavior  Compassion and Empathy  ...            NaN       NaN
# 5             Wait Time               Call back  ...            NaN       NaN
# 6               Finance                 Billing  ...            NaN       NaN
# 7      Decedent Affairs             End of Life  ...            NaN       NaN
# 8          Care Quality          Responsiveness  ...      Follow up       NaN
# 9             Treatment               Procedure  ...            NaN       NaN
#
# [10 rows x 7 columns]

# %%
# Step 2: Converting the classes & subclasses to predict into a dictionary

# Using Melt to aggregate the layers
df_layers = layers.melt(id_vars=["Subtheme"],
             var_name="Subclass",  
             value_name="Topics")

# Cleaning the themes 
df_layers = df_layers.dropna()
df_layers.drop('Subclass', inplace=True, axis=1)

# Converting the dataframe to final dictionary
thisdict={k: g["Topics"].tolist() for k,g in df_layers.groupby("Subtheme")}

# A look into the Dictionary of Subthemes & subclasses
pprint.pprint(thisdict)
# Out:
# {'Abuse Allegations': ['Physical', 'Verbal', 'Sexual'],
#  'Behavior': ['Compassion and Empathy', 'Rude', 'Attentive', 'Dismissive'],
#  'Care Quality': ['Responsiveness',
#                   'Listening',
#                   'Knowledgeable',
#                   'Detailed',
#                   'Follow up'],
#  'Cleaniless': ['Patient Area', 'Public Space', 'Personal Hygiene'],
#  'Communication': ['Doctor', 'Interpreter', 'Staff', 'Interns'],
#  'Decedent Affairs': ['End of Life', 'Withdrawl of Care'],
#  'Diagnosis': ['Tests',
#                'Reports',
#                'Explanation',
#                'Charts',
#                'Explanation',
#                'Interpretation'],
#  'Finance': ['Billing', 'Cost of Care', 'Discharge Dispute'],
#  'Interpersonal': ['Empathy', 'Friendly', 'Patience', 'Honesty'],
#  'Medication': ['Pain Management',
#                 'Infection Control',
#                 'Plan of Care',
#                 'Prescription',
#                 'Communication'],
#  'Physical Enviornment': ['Noise', 'Parking', 'Temperature', 'Ambience'],
#  'Room Issues': ['Roommate',
#                  'Bathroom Cleaning',
#                  'Noise',
#                  'Staff courtesy',
#                  'Comfort',
#                  'Bedding'],
#  'Treatment': ['Procedure', 'Surgery', 'Blood Drawing', 'Tests'],
#  'Visitor Care': ['Space',
#                   'Furniture',
#                   'Courtsey Respect',
#                   'Other Visitor Complaints',
#                   'Restrooms'],
#  'Wait Time': ['Call back', 'Waiting', 'Telephone Acess']}

# %%
# Step 3: Setting up the zero-shot classifier
zero_shot_classifier = pipeline('zero-shot-classification', model='facebook/bart-large-mnli', device=0)

# %%
# Step 4: Zero-shot classification for only 'One class'
classes = layers['Subtheme']
hypothesis_template = "This text is about {}."

# Initializing the objects
d = []
predicted_class = ""

# Iterating through the reviews
for i, row in reviews.iterrows():
    predicted_class = ""
    text = row['text']
    text = ftfy.fix_text(text)
    text = text.translate(str.maketrans(dict.fromkeys(string.punctuation)))
    results = zero_shot_classifier(text, classes, hypothesis_template=hypothesis_template, multi_label=True)
    SCORES = results["scores"]
    CLASSES = results["labels"]
    BEST_INDEX = argmax(SCORES)
    predicted_class = CLASSES[BEST_INDEX]
    d.append(
        {
            'text': row['text'],
            'predicted_class1': CLASSES[BEST_INDEX],
            'predicted_class2': CLASSES[BEST_INDEX+1],
            'predicted_class3': CLASSES[BEST_INDEX+2],
            'predicted_class4': CLASSES[BEST_INDEX+3]
        }
    )
    print("Classifying the " + str(i+1) + " review")

print("Classification Complete")

# Downloading the final result 
from google.colab import files
df_ZeroShot_OnlyClasses = pd.DataFrame(d)
df_ZeroShot_OnlyClasses.to_csv('Topic_Model_ZeroShot_OnlyClasses.csv', index=False)
files.download('Topic_Model_ZeroShot_OnlyClasses.csv')
# Out:
# Classifying the 1 review
# Classifying the 2 review
# Classifying the 3 review
# Classifying the 4 review
# Classifying the 5 review
# Classifying the 6 review
# Classifying the 7 review
# Classifying the 8 review
# Classifying the 9 review
# Classifying the 10 review
# Classifying the 11 review
# Classifying the 12 review
# Classifying the 13 review
# Classifying the 14 review
# Classifying the 15 review
# Classifying the 16 review
# Classifying the 17 review
# Classifying the 18 review
# Classifying the 19 review
# Classifying the 20 review
# Classifying the 21 review
# Classifying the 22 review
# Classifying the 23 review
# Classifying the 24 review
# Classifying the 25 review
# Classifying the 26 review
# Classifying the 27 review
# Classifying the 28 review
# Classifying the 29 review
# Classifying the 30 review
# Classifying the 31 review
# Classifying the 32 review
# Classifying the 33 review
# Classifying the 34 review
# Classifying the 35 review
# Classifying the 36 review
# Classifying the 37 review
# Classifying the 38 review
# Classifying the 39 review
# Classifying the 40 review
# Classifying the 41 review
# Classifying the 42 review
# Classifying the 43 review
# Classifying the 44 review
# Classifying the 45 review
# Classifying the 46 review
# Classifying the 47 review
# Classifying the 48 review
# Classifying the 49 review
# Classifying the 50 review
# Classifying the 51 review
# Classifying the 52 review
# Classifying the 53 review
# Classifying the 54 review
# Classifying the 55 review
# Classifying the 56 review
# Classifying the 57 review
# Classifying the 58 review
# Classifying the 59 review
# Classifying the 60 review
# Classifying the 61 review
# Classifying the 62 review
# Classifying the 63 review
# Classifying the 64 review
# Classifying the 65 review
# Classifying the 66 review
# Classifying the 67 review
# Classifying the 68 review
# Classifying the 69 review
# Classifying the 70 review
# Classifying the 71 review
# Classifying the 72 review
# Classifying the 73 review
# Classifying the 74 review
# Classifying the 75 review
# Classifying the 76 review
# Classifying the 77 review
# Classifying the 78 review
# Classifying the 79 review
# Classifying the 80 review
# Classifying the 81 review
# Classifying the 82 review
# Classifying the 83 review
# Classifying the 84 review
# Classifying the 85 review
# Classifying the 86 review
# Classifying the 87 review
# Classifying the 88 review
# Classifying the 89 review
# Classifying the 90 review
# Classifying the 91 review
# Classifying the 92 review
# Classifying the 93 review
# Classifying the 94 review
# Classifying the 95 review
# Classifying the 96 review
# Classifying the 97 review
# Classifying the 98 review
# Classifying the 99 review
# Classifying the 100 review
# Classifying the 101 review
# Classifying the 102 review
# Classifying the 103 review
# Classifying the 104 review
# Classifying the 105 review
# Classifying the 106 review
# Classifying the 107 review
# Classifying the 108 review
# Classifying the 109 review
# Classifying the 110 review
# Classifying the 111 review
# Classifying the 112 review
# Classifying the 113 review
# Classifying the 114 review
# Classifying the 115 review
# Classifying the 116 review
# Classifying the 117 review
# Classifying the 118 review
# Classifying the 119 review
# Classifying the 120 review
# Classifying the 121 review
# Classifying the 122 review
# Classifying the 123 review
# Classifying the 124 review
# Classifying the 125 review
# Classifying the 126 review
# Classifying the 127 review
# Classifying the 128 review
# Classifying the 129 review
# Classifying the 130 review
# Classifying the 131 review
# Classifying the 132 review
# Classifying the 133 review
# Classifying the 134 review
# Classifying the 135 review
# Classifying the 136 review
# Classifying the 137 review
# Classifying the 138 review
# Classifying the 139 review
# Classifying the 140 review
# Classifying the 141 review
# Classifying the 142 review
# Classifying the 143 review
# Classifying the 144 review
# Classifying the 145 review
# Classifying the 146 review
# Classifying the 147 review
# Classifying the 148 review
# Classifying the 149 review
# Classifying the 150 review
# Classifying the 151 review
# Classifying the 152 review
# Classifying the 153 review
# Classifying the 154 review
# Classifying the 155 review
# Classifying the 156 review
# Classifying the 157 review
# Classifying the 158 review
# Classifying the 159 review
# Classifying the 160 review
# Classifying the 161 review
# Classifying the 162 review
# Classifying the 163 review
# Classifying the 164 review
# Classifying the 165 review
# Classifying the 166 review
# Classifying the 167 review
# Classifying the 168 review
# Classifying the 169 review
# Classifying the 170 review
# Classifying the 171 review
# Classifying the 172 review
# Classifying the 173 review
# Classifying the 174 review
# Classifying the 175 review
# Classifying the 176 review
# Classifying the 177 review
# Classifying the 178 review
# Classifying the 179 review
# Classifying the 180 review
# Classifying the 181 review
# Classifying the 182 review
# Classifying the 183 review
# Classifying the 184 review
# Classifying the 185 review
# Classifying the 186 review
# Classifying the 187 review
# Classifying the 188 review
# Classifying the 189 review
# Classifying the 190 review
# Classifying the 191 review
# Classifying the 192 review
# Classifying the 193 review
# Classifying the 194 review
# Classifying the 195 review
# Classifying the 196 review
# Classifying the 197 review
# Classifying the 198 review
# Classifying the 199 review
# Classifying the 200 review
# Classifying the 201 review
# Classifying the 202 review
# Classifying the 203 review
# Classifying the 204 review
# Classifying the 205 review
# Classifying the 206 review
# Classifying the 207 review
# Classifying the 208 review
# Classifying the 209 review
# Classifying the 210 review
# Classifying the 211 review
# Classifying the 212 review
# Classifying the 213 review
# Classifying the 214 review
# Classifying the 215 review
# Classifying the 216 review
# Classifying the 217 review
# Classifying the 218 review
# Classifying the 219 review
# Classifying the 220 review
# Classifying the 221 review
# Classifying the 222 review
# Classifying the 223 review
# Classifying the 224 review
# Classifying the 225 review
# Classifying the 226 review
# Classifying the 227 review
# Classifying the 228 review
# Classifying the 229 review
# Classifying the 230 review
# Classifying the 231 review
# Classifying the 232 review
# Classifying the 233 review
# Classifying the 234 review
# Classifying the 235 review
# Classifying the 236 review
# Classifying the 237 review
# Classifying the 238 review
# Classifying the 239 review
# Classifying the 240 review
# Classifying the 241 review
# Classifying the 242 review
# Classifying the 243 review
# Classifying the 244 review
# Classifying the 245 review
# Classifying the 246 review
# Classifying the 247 review
# Classifying the 248 review
# Classifying the 249 review
# Classifying the 250 review
# Classifying the 251 review
# Classifying the 252 review
# Classifying the 253 review
# Classifying the 254 review
# Classifying the 255 review
# Classifying the 256 review
# Classifying the 257 review
# Classifying the 258 review
# Classifying the 259 review
# Classifying the 260 review
# Classifying the 261 review
# Classifying the 262 review
# Classifying the 263 review
# Classifying the 264 review
# Classifying the 265 review
# Classifying the 266 review
# Classifying the 267 review
# Classifying the 268 review
# Classification Complete

# %%
# Step 5: Zero-shot classification for only 'Multi Subclass'
classes = layers['Subtheme']
hypothesis_template = "This text is about {}."

# Initializing the objects
d = []
predicted_class = ""

# Iterating through the reviews
for i, row in reviews.iterrows():
    predicted_class = ""
    text = row['text']
    text = ftfy.fix_text(text)
    text = text.translate(str.maketrans(dict.fromkeys(string.punctuation)))
    results = zero_shot_classifier(text, classes, hypothesis_template=hypothesis_template, multi_label=True)
    SCORES = results["scores"]
    CLASSES = results["labels"]
    BEST_INDEX = argmax(SCORES)
    predicted_class = CLASSES[BEST_INDEX]
    
    # For the first topic
    nc = thisdict[predicted_class]
    results_sub = zero_shot_classifier(text, nc, hypothesis_template=hypothesis_template, multi_label=True)
    SCORES_sub = results_sub["scores"]
    CLASSES_sub = results_sub["labels"]
    BEST_INDEX_sub = argmax(SCORES_sub)
    predicted_class_sub1 = CLASSES_sub[BEST_INDEX_sub]
    
    # For the second topic
    predicted_class = CLASSES[BEST_INDEX+1]
    nc = thisdict[predicted_class]
    results_sub = zero_shot_classifier(text, nc, hypothesis_template=hypothesis_template, multi_label=True)
    SCORES_sub = results_sub["scores"]
    CLASSES_sub = results_sub["labels"]
    BEST_INDEX_sub = argmax(SCORES_sub)
    predicted_class_sub2 = CLASSES_sub[BEST_INDEX_sub]
   
    # For the third topic
    predicted_class = CLASSES[BEST_INDEX+2]
    nc = thisdict[predicted_class]
    results_sub = zero_shot_classifier(text, nc, hypothesis_template=hypothesis_template, multi_label=True)
    SCORES_sub = results_sub["scores"]
    CLASSES_sub = results_sub["labels"]
    BEST_INDEX_sub = argmax(SCORES_sub)
    predicted_class_sub3 = CLASSES_sub[BEST_INDEX_sub]
       
    # For the fourth topic
    predicted_class = CLASSES[BEST_INDEX+3]
    nc = thisdict[predicted_class]
    results_sub = zero_shot_classifier(text, nc, hypothesis_template=hypothesis_template, multi_label=True)
    SCORES_sub = results_sub["scores"]
    CLASSES_sub = results_sub["labels"]
    BEST_INDEX_sub = argmax(SCORES_sub)
    predicted_class_sub4 = CLASSES_sub[BEST_INDEX_sub]
    
    d.append(
            {
                'text': row['text'],
                'predicted_class1': CLASSES[BEST_INDEX],
                'predicted_class2': CLASSES[BEST_INDEX+1],
                'predicted_class3': CLASSES[BEST_INDEX+2],
                'predicted_class4': CLASSES[BEST_INDEX+3],
                'predicted_sub1': predicted_class_sub1,
                'predicted_sub2': predicted_class_sub2,
                'predicted_sub3': predicted_class_sub3,
                'predicted_sub4': predicted_class_sub4
            }
        )
    print("Classifying the " + str(i+1) + " review")

print("Classification Complete")

# Downloading the final result 
from google.colab import files
df_ZeroShot_MultiSubclass = pd.DataFrame(d)
df_ZeroShot_MultiSubclass.to_csv('Topic_Model_ZeroShot_MultiSubclass.csv', index=False)
files.download('Topic_Model_ZeroShot_MultiSubclass.csv')
# Out:
# Classifying the 1 review
# Classifying the 2 review
# Classifying the 3 review
# Classifying the 4 review
# Classifying the 5 review
# Classifying the 6 review
# Classifying the 7 review
# Classifying the 8 review
# Classifying the 9 review
# Classifying the 10 review
# Classifying the 11 review
# Classifying the 12 review
# Classifying the 13 review
# Classifying the 14 review
# Classifying the 15 review
# Classifying the 16 review
# Classifying the 17 review
# Classifying the 18 review
# Classifying the 19 review
# Classifying the 20 review
# Classifying the 21 review
# Classifying the 22 review
# Classifying the 23 review
# Classifying the 24 review
# Classifying the 25 review
# Classifying the 26 review
# Classifying the 27 review
# Classifying the 28 review
# Classifying the 29 review
# Classifying the 30 review
# Classifying the 31 review
# Classifying the 32 review
# Classifying the 33 review
# Classifying the 34 review
# Classifying the 35 review
# Classifying the 36 review
# Classifying the 37 review
# Classifying the 38 review
# Classifying the 39 review
# Classifying the 40 review
# Classifying the 41 review
# Classifying the 42 review
# Classifying the 43 review
# Classifying the 44 review
# Classifying the 45 review
# Classifying the 46 review
# Classifying the 47 review
# Classifying the 48 review
# Classifying the 49 review
# Classifying the 50 review
# Classifying the 51 review
# Classifying the 52 review
# Classifying the 53 review
# Classifying the 54 review
# Classifying the 55 review
# Classifying the 56 review
# Classifying the 57 review
# Classifying the 58 review
# Classifying the 59 review
# Classifying the 60 review
# Classifying the 61 review
# Classifying the 62 review
# Classifying the 63 review
# Classifying the 64 review
# Classifying the 65 review
# Classifying the 66 review
# Classifying the 67 review
# Classifying the 68 review
# Classifying the 69 review
# Classifying the 70 review
# Classifying the 71 review
# Classifying the 72 review
# Classifying the 73 review
# Classifying the 74 review
# Classifying the 75 review
# Classifying the 76 review
# Classifying the 77 review
# Classifying the 78 review
# Classifying the 79 review
# Classifying the 80 review
# Classifying the 81 review
# Classifying the 82 review
# Classifying the 83 review
# Classifying the 84 review
# Classifying the 85 review
# Classifying the 86 review
# Classifying the 87 review
# Classifying the 88 review
# Classifying the 89 review
# Classifying the 90 review
# Classifying the 91 review
# Classifying the 92 review
# Classifying the 93 review
# Classifying the 94 review
# Classifying the 95 review
# Classifying the 96 review
# Classifying the 97 review
# Classifying the 98 review
# Classifying the 99 review
# Classifying the 100 review
# Classifying the 101 review
# Classifying the 102 review
# Classifying the 103 review
# Classifying the 104 review
# Classifying the 105 review
# Classifying the 106 review
# Classifying the 107 review
# Classifying the 108 review
# Classifying the 109 review
# Classifying the 110 review
# Classifying the 111 review
# Classifying the 112 review
# Classifying the 113 review
# Classifying the 114 review
# Classifying the 115 review
# Classifying the 116 review
# Classifying the 117 review
# Classifying the 118 review
# Classifying the 119 review
# Classifying the 120 review
# Classifying the 121 review
# Classifying the 122 review
# Classifying the 123 review
# Classifying the 124 review
# Classifying the 125 review
# Classifying the 126 review
# Classifying the 127 review
# Classifying the 128 review
# Classifying the 129 review
# Classifying the 130 review
# Classifying the 131 review
# Classifying the 132 review
# Classifying the 133 review
# Classifying the 134 review
# Classifying the 135 review
# Classifying the 136 review
# Classifying the 137 review
# Classifying the 138 review
# Classifying the 139 review
# Classifying the 140 review
# Classifying the 141 review
# Classifying the 142 review
# Classifying the 143 review
# Classifying the 144 review
# Classifying the 145 review
# Classifying the 146 review
# Classifying the 147 review
# Classifying the 148 review
# Classifying the 149 review
# Classifying the 150 review
# Classifying the 151 review
# Classifying the 152 review
# Classifying the 153 review
# Classifying the 154 review
# Classifying the 155 review
# Classifying the 156 review
# Classifying the 157 review
# Classifying the 158 review
# Classifying the 159 review
# Classifying the 160 review
# Classifying the 161 review
# Classifying the 162 review
# Classifying the 163 review
# Classifying the 164 review
# Classifying the 165 review
# Classifying the 166 review
# Classifying the 167 review
# Classifying the 168 review
# Classifying the 169 review
# Classifying the 170 review
# Classifying the 171 review
# Classifying the 172 review
# Classifying the 173 review
# Classifying the 174 review
# Classifying the 175 review
# Classifying the 176 review
# Classifying the 177 review
# Classifying the 178 review
# Classifying the 179 review
# Classifying the 180 review
# Classifying the 181 review
# Classifying the 182 review
# Classifying the 183 review
# Classifying the 184 review
# Classifying the 185 review
# Classifying the 186 review
# Classifying the 187 review
# Classifying the 188 review
# Classifying the 189 review
# Classifying the 190 review
# Classifying the 191 review
# Classifying the 192 review
# Classifying the 193 review
# Classifying the 194 review
# Classifying the 195 review
# Classifying the 196 review
# Classifying the 197 review
# Classifying the 198 review
# Classifying the 199 review
# Classifying the 200 review
# Classifying the 201 review
# Classifying the 202 review
# Classifying the 203 review
# Classifying the 204 review
# Classifying the 205 review
# Classifying the 206 review
# Classifying the 207 review
# Classifying the 208 review
# Classifying the 209 review
# Classifying the 210 review
# Classifying the 211 review
# Classifying the 212 review
# Classifying the 213 review
# Classifying the 214 review
# Classifying the 215 review
# Classifying the 216 review
# Classifying the 217 review
# Classifying the 218 review
# Classifying the 219 review
# Classifying the 220 review
# Classifying the 221 review
# Classifying the 222 review
# Classifying the 223 review
# Classifying the 224 review
# Classifying the 225 review
# Classifying the 226 review
# Classifying the 227 review
# Classifying the 228 review
# Classifying the 229 review
# Classifying the 230 review
# Classifying the 231 review
# Classifying the 232 review
# Classifying the 233 review
# Classifying the 234 review
# Classifying the 235 review
# Classifying the 236 review
# Classifying the 237 review
# Classifying the 238 review
# Classifying the 239 review
# Classifying the 240 review
# Classifying the 241 review
# Classifying the 242 review
# Classifying the 243 review
# Classifying the 244 review
# Classifying the 245 review
# Classifying the 246 review
# Classifying the 247 review
# Classifying the 248 review
# Classifying the 249 review
# Classifying the 250 review
# Classifying the 251 review
# Classifying the 252 review
# Classifying the 253 review
# Classifying the 254 review
# Classifying the 255 review
# Classifying the 256 review
# Classifying the 257 review
# Classifying the 258 review
# Classifying the 259 review
# Classifying the 260 review
# Classifying the 261 review
# Classifying the 262 review
# Classifying the 263 review
# Classifying the 264 review
# Classifying the 265 review
# Classifying the 266 review
# Classifying the 267 review
# Classifying the 268 review
# Classification Complete

# %% [markdown]
# ### *Congratulations on your 1st Zero-shot Classifier*
